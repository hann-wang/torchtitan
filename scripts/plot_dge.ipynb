# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

import torch
from matplotlib import pyplot as plt

from torchtitan.experiments.kernels.blockwise_fp8.differentiable_gradient_estimator import dge_fwd, dge_bwd
dtype = torch.float8_e4m3fnuz
# q = torch.randn(64, 64)
# dge_bwd(q, dtype)
# Out:
# tensor([[0.5604, 0.2197, 0.4705,  ..., 0.5280, 0.7323, 0.2579],
#         [0.7399, 0.3823, 3.0000,  ..., 0.2027, 0.7476, 0.3833],
#         [0.5280, 0.2011, 1.2995,  ..., 0.5038, 0.5806, 0.2710],
#         ...,
#         [0.2434, 0.2693, 0.8933,  ..., 0.2650, 0.9717, 0.5546],
#         [0.2326, 0.7138, 0.6941,  ..., 0.2284, 0.9467, 0.2041],
#         [0.9433, 0.4327, 0.2235,  ..., 0.4366, 0.5552, 3.0000]])

# %%
x = torch.arange(1, 1.25, 1e-3)
#x = torch.arange(-240, 240, 1e-3)
y = dge_fwd(x, dtype)
qx = x.to(dtype).to(torch.float32)

plt.plot(x.numpy(), x.numpy(), label="STE")
plt.plot(x.numpy(), qx.numpy(), label="Hard")
plt.plot(x.numpy(), y.numpy(), label="DGE Forward")
plt.show()

# %%
dy = dge_bwd(y, dtype)
plt.plot(x.numpy(), dy.numpy(), label="DGE Backward")
plt.plot(x.numpy(), torch.ones_like(x).numpy(), label="STE Backward")
plt.show()
