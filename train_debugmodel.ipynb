# %%
import os
import sys
import logging

logging.basicConfig(stream=sys.stdout, level=logging.DEBUG)

os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# os.environ["TRITON_DEBUG"] = "1"
# os.environ["FLASH_ATTENTION_TRITON_AMD_DEBUG"] = "1"
os.environ["FLASH_ATTENTION_TRITON_AMD_AUTOTUNE"] = os.environ[
    "TRITON_PRINT_AUTOTUNING "] = "0"

# os.environ["TORCH_LOGS"] = "+dynamo"
# os.environ["TORCHDYNAMO_VERBOSE"] = "1"

#sys.path.append(os.path.realpath('.'))

from typing import Optional
import torch

from torchtitan.config_manager import JobConfig
from torchtitan.tools.logging import init_logger, logger
from torchtitan.train import Trainer

init_logger()
config_file_path = "./torchtitan/experiments/opt/train_configs/debug_model.toml"
#config_file_path = "./torchtitan/models/llama3/train_configs/debug_model.toml"

config = JobConfig()
config.parse_args(["--job.config_file", config_file_path])
print(config.to_dict())
trainer: Optional[Trainer] = None
trainer = Trainer(config)
# Out:
# INFO:datasets:PyTorch version 2.8.0.dev20250325+rocm6.2.4 available.
# defaultdict(<class 'collections.defaultdict'>, {'job': defaultdict(None, {'config_file': './torchtitan/experiments/opt/train_configs/debug_model.toml', 'dump_folder': './outputs', 'description': 'OPT-125m debug training', 'use_for_integration_test': True, 'print_args': False}), 'profiling': defaultdict(None, {'enable_profiling': False, 'save_traces_folder': 'profile_trace', 'profile_freq': 10, 'enable_memory_snapshot': False, 'save_memory_snapshot_folder': 'memory_snapshot'}), 'metrics': defaultdict(None, {'log_freq': 1, 'enable_tensorboard': False, 'disable_color_printing': False, 'save_tb_folder': 'tb', 'save_for_all_ranks': False, 'enable_wandb': False}), 'model': defaultdict(None, {'name': 'opt', 'path': '/workspace/hf_home/hub/models--facebook--opt-125m/snapshots/27dcfa74d334bc871f3234de431e71c6eeba5dd6', 'flavor': '125m', 'norm_type': 'dynamic_tanh', 'use_flex_attn': False, 'attn_mask_type': 'causal', 'tokenizer_path': '/workspace/hf_home/hub/models--facebook--opt-125m/snapshots/27dcfa74d334bc871f3234de431e71c6eeba5dd6', 'converters': ['float8'], 'print_after_conversion': False}), 'optimizer': defaultdict(None, {'name': 'AdamW', 'lr': 0.0008, 'eps': 1e-08, 'implementation': 'fused', 'early_step_in_backward': False}), 'lr_scheduler': defaultdict(None, {'warmup_steps': 2, 'decay_ratio': 0.8, 'decay_type': 'linear', 'lr_min': 0.0}), 'training': defaultdict(None, {'dataset': 'c4_test', 'dataset_path': None, 'batch_size': 8, 'seq_len': 2048, 'max_norm': 1.0, 'steps': 10, 'enable_cpu_offload': False, 'mixed_precision_param': 'bfloat16', 'mixed_precision_reduce': 'float32', 'compile': False, 'gc_freq': 50, 'seed': None, 'deterministic': False}), 'parallelism': defaultdict(None, {'data_parallel_replicate_degree': 1, 'enable_compiled_autograd': False, 'data_parallel_shard_degree': -1, 'fsdp_reshard_after_forward': 'default', 'tensor_parallel_degree': 1, 'disable_loss_parallel': False, 'enable_async_tensor_parallel': False, 'pipeline_parallel_degree': 1, 'pipeline_parallel_split_points': [], 'pipeline_parallel_layers_per_stage': None, 'pipeline_parallel_schedule': '1F1B', 'pipeline_parallel_schedule_csv': '', 'pipeline_parallel_microbatch_size': 1, 'context_parallel_degree': 1, 'context_parallel_rotate_method': 'allgather'}), 'checkpoint': defaultdict(None, {'enable_checkpoint': False, 'folder': 'checkpoint', 'interval': 10, 'model_weights_only': False, 'export_dtype': 'float32', 'create_seed_checkpoint': False, 'async_mode': 'disabled', 'keep_latest_k': 10, 'load_step': -1, 'exclude_from_loading': []}), 'activation_checkpoint': defaultdict(None, {'mode': 'none', 'selective_ac_option': '2'}), 'float8': defaultdict(None, {'enable_fsdp_float8_all_gather': False, 'precompute_float8_dynamic_scale_for_fsdp': False, 'force_recompute_fp8_weight_in_bwd': False, 'recipe_name': None, 'filter_fqns': [], 'enable_fp8_fa': True, 'fp8_fa_granularity': 'blockwise'}), 'comm': defaultdict(None, {'init_timeout_seconds': 300, 'train_timeout_seconds': 100, 'trace_buf_size': 20000}), 'memory_estimation': defaultdict(None, {'enabled': False, 'disable_fake_mode': False}), 'fault_tolerance': defaultdict(None, {'enable': False, 'replica_id': 0, 'group_size': 0, 'min_replica_size': 1}), 'experimental': defaultdict(None, {'custom_import': '', 'custom_args_module': ''})})
# INFO:root:Starting job: OPT-125m debug training
# [titan] 2025-04-21 09:40:11,219 - root - INFO - Starting job: OPT-125m debug training
# INFO:root:[GC] Initial GC collection. 0.00 seconds.
# [titan] 2025-04-21 09:40:11,221 - root - INFO - [GC] Initial GC collection. 0.00 seconds.
# INFO:root:Preparing c4_test dataset from tests/assets/c4_test
# /workspace/transformers/src/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# [titan] 2025-04-21 09:40:11,293 - root - INFO - Preparing c4_test dataset from tests/assets/c4_test
# INFO:root:Building HF Transformers model with /workspace/hf_home/hub/models--facebook--opt-125m/snapshots/27dcfa74d334bc871f3234de431e71c6eeba5dd6
# [titan] 2025-04-21 09:40:11,326 - root - INFO - Building HF Transformers model with /workspace/hf_home/hub/models--facebook--opt-125m/snapshots/27dcfa74d334bc871f3234de431e71c6eeba5dd6
# Flash Attention 2.0 only supports torch.float16 and torch.bfloat16 dtypes, but the current dype in OPTForCausalLM is torch.float32. You should run training or inference using Automatic Mixed-Precision via the `with torch.autocast(device_type='torch_device'):` decorator, or load the model with the `torch_dtype` argument. Example: `model = AutoModel.from_pretrained("openai/whisper-tiny", attn_implementation="flash_attention_2", torch_dtype=torch.float16)`
# Flash Attention 2.0 only supports torch.float16 and torch.bfloat16 dtypes, but the current dype in OPTModel is torch.float32. You should run training or inference using Automatic Mixed-Precision via the `with torch.autocast(device_type='torch_device'):` decorator, or load the model with the `torch_dtype` argument. Example: `model = AutoModel.from_pretrained("openai/whisper-tiny", attn_implementation="flash_attention_2", torch_dtype=torch.float16)`
# Flash Attention 2.0 only supports torch.float16 and torch.bfloat16 dtypes, but the current dype in OPTDecoder is torch.float32. You should run training or inference using Automatic Mixed-Precision via the `with torch.autocast(device_type='torch_device'):` decorator, or load the model with the `torch_dtype` argument. Example: `model = AutoModel.from_pretrained("openai/whisper-tiny", attn_implementation="flash_attention_2", torch_dtype=torch.float16)`
# INFO:root:Float8 tensorwise scaled training active
# [titan] 2025-04-21 09:40:11,370 - root - INFO - Float8 tensorwise scaled training active
# INFO:root:Swapped to Float8Linear layers with enable_fsdp_float8_all_gather=False
# [titan] 2025-04-21 09:40:11,378 - root - INFO - Swapped to Float8Linear layers with enable_fsdp_float8_all_gather=False
# INFO:root:Enable FP8 kernel for OptFlashAttention2 with use_fp8_fa_block_scales=True.
# [titan] 2025-04-21 09:40:11,379 - root - INFO - Enable FP8 kernel for OptFlashAttention2 with use_fp8_fa_block_scales=True.
# INFO:root:Enable FP8 kernel for OptFlashAttention2 with use_fp8_fa_block_scales=True.
# [titan] 2025-04-21 09:40:11,380 - root - INFO - Enable FP8 kernel for OptFlashAttention2 with use_fp8_fa_block_scales=True.
# INFO:root:Enable FP8 kernel for OptFlashAttention2 with use_fp8_fa_block_scales=True.
# [titan] 2025-04-21 09:40:11,382 - root - INFO - Enable FP8 kernel for OptFlashAttention2 with use_fp8_fa_block_scales=True.
# INFO:root:Enable FP8 kernel for OptFlashAttention2 with use_fp8_fa_block_scales=True.
# [titan] 2025-04-21 09:40:11,383 - root - INFO - Enable FP8 kernel for OptFlashAttention2 with use_fp8_fa_block_scales=True.
# INFO:root:Enable FP8 kernel for OptFlashAttention2 with use_fp8_fa_block_scales=True.
# [titan] 2025-04-21 09:40:11,384 - root - INFO - Enable FP8 kernel for OptFlashAttention2 with use_fp8_fa_block_scales=True.
# INFO:root:Enable FP8 kernel for OptFlashAttention2 with use_fp8_fa_block_scales=True.
# [titan] 2025-04-21 09:40:11,385 - root - INFO - Enable FP8 kernel for OptFlashAttention2 with use_fp8_fa_block_scales=True.
# INFO:root:Enable FP8 kernel for OptFlashAttention2 with use_fp8_fa_block_scales=True.
# [titan] 2025-04-21 09:40:11,386 - root - INFO - Enable FP8 kernel for OptFlashAttention2 with use_fp8_fa_block_scales=True.
# INFO:root:Enable FP8 kernel for OptFlashAttention2 with use_fp8_fa_block_scales=True.
# [titan] 2025-04-21 09:40:11,387 - root - INFO - Enable FP8 kernel for OptFlashAttention2 with use_fp8_fa_block_scales=True.
# INFO:root:Enable FP8 kernel for OptFlashAttention2 with use_fp8_fa_block_scales=True.
# [titan] 2025-04-21 09:40:11,388 - root - INFO - Enable FP8 kernel for OptFlashAttention2 with use_fp8_fa_block_scales=True.
# INFO:root:Enable FP8 kernel for OptFlashAttention2 with use_fp8_fa_block_scales=True.
# [titan] 2025-04-21 09:40:11,389 - root - INFO - Enable FP8 kernel for OptFlashAttention2 with use_fp8_fa_block_scales=True.
# INFO:root:Enable FP8 kernel for OptFlashAttention2 with use_fp8_fa_block_scales=True.
# [titan] 2025-04-21 09:40:11,390 - root - INFO - Enable FP8 kernel for OptFlashAttention2 with use_fp8_fa_block_scales=True.
# INFO:root:Enable FP8 kernel for OptFlashAttention2 with use_fp8_fa_block_scales=True.
# [titan] 2025-04-21 09:40:11,391 - root - INFO - Enable FP8 kernel for OptFlashAttention2 with use_fp8_fa_block_scales=True.
# INFO:root:CUDA capacity: AMD Radeon Graphics with 191.98GiB memory
# [titan] 2025-04-21 09:40:11,393 - root - INFO - CUDA capacity: AMD Radeon Graphics with 191.98GiB memory
# INFO:root:Model opt 125m size: 163,848,192 total parameters
# [titan] 2025-04-21 09:40:11,467 - root - INFO - Model opt 125m size: 163,848,192 total parameters
# INFO:root:Peak FLOPS used for computing MFU: 2.030e+14
# [titan] 2025-04-21 09:40:11,762 - root - INFO - Peak FLOPS used for computing MFU: 2.030e+14
# INFO:root:CUDA memory usage for model: 0.81GiB(0.42%)
# [titan] 2025-04-21 09:40:11,765 - root - INFO - CUDA memory usage for model: 0.81GiB(0.42%)
# INFO:root:Trainer is initialized with local batch size 8, global batch size 8, sequence length 2048, total steps 10 (warmup 2).
# [titan] 2025-04-21 09:40:11,769 - root - INFO - Trainer is initialized with local batch size 8, global batch size 8, sequence length 2048, total steps 10 (warmup 2).

# %%
trainer.train()
# Out:
# INFO:root:Training starts at step 1.
# [titan] 2025-04-21 09:40:11,781 - root - INFO - Training starts at step 1.
# INFO:root:step:  1  loss: 352.1626  memory: 15.71GiB(8.18%)  tps: 1,362  tflops: 1.65  mfu: 0.81%
# [titan] 2025-04-21 09:40:23,494 - root - INFO - step:  1  loss: 352.1626  memory: 15.71GiB(8.18%)  tps: 1,362  tflops: 1.65  mfu: 0.81%
# INFO:root:step:  2  loss: 138.0264  memory: 15.71GiB(8.18%)  tps: 24,880  tflops: 30.09  mfu: 14.82%
# [titan] 2025-04-21 09:40:24,156 - root - INFO - step:  2  loss: 138.0264  memory: 15.71GiB(8.18%)  tps: 24,880  tflops: 30.09  mfu: 14.82%
# INFO:root:step:  3  loss: 96.7274  memory: 15.71GiB(8.18%)  tps: 24,775  tflops: 29.97  mfu: 14.76%
# [titan] 2025-04-21 09:40:24,821 - root - INFO - step:  3  loss: 96.7274  memory: 15.71GiB(8.18%)  tps: 24,775  tflops: 29.97  mfu: 14.76%
# INFO:root:step:  4  loss: 94.7087  memory: 15.71GiB(8.18%)  tps: 24,673  tflops: 29.84  mfu: 14.70%
# [titan] 2025-04-21 09:40:25,489 - root - INFO - step:  4  loss: 94.7087  memory: 15.71GiB(8.18%)  tps: 24,673  tflops: 29.84  mfu: 14.70%
# INFO:root:step:  5  loss: 88.2599  memory: 15.71GiB(8.18%)  tps: 24,699  tflops: 29.88  mfu: 14.72%
# [titan] 2025-04-21 09:40:26,157 - root - INFO - step:  5  loss: 88.2599  memory: 15.71GiB(8.18%)  tps: 24,699  tflops: 29.88  mfu: 14.72%
# INFO:root:step:  6  loss: 87.6592  memory: 15.71GiB(8.18%)  tps: 24,746  tflops: 29.93  mfu: 14.74%
# [titan] 2025-04-21 09:40:26,822 - root - INFO - step:  6  loss: 87.6592  memory: 15.71GiB(8.18%)  tps: 24,746  tflops: 29.93  mfu: 14.74%
# INFO:root:step:  7  loss: 84.7014  memory: 15.71GiB(8.18%)  tps: 24,366  tflops: 29.47  mfu: 14.52%
# [titan] 2025-04-21 09:40:27,498 - root - INFO - step:  7  loss: 84.7014  memory: 15.71GiB(8.18%)  tps: 24,366  tflops: 29.47  mfu: 14.52%
# INFO:root:step:  8  loss: 81.8616  memory: 15.71GiB(8.18%)  tps: 25,078  tflops: 30.33  mfu: 14.94%
# [titan] 2025-04-21 09:40:28,155 - root - INFO - step:  8  loss: 81.8616  memory: 15.71GiB(8.18%)  tps: 25,078  tflops: 30.33  mfu: 14.94%
# INFO:root:step:  9  loss: 78.1487  memory: 15.71GiB(8.18%)  tps: 24,705  tflops: 29.88  mfu: 14.72%
# [titan] 2025-04-21 09:40:28,822 - root - INFO - step:  9  loss: 78.1487  memory: 15.71GiB(8.18%)  tps: 24,705  tflops: 29.88  mfu: 14.72%
# INFO:root:step: 10  loss: 74.4812  memory: 15.71GiB(8.18%)  tps: 24,702  tflops: 29.88  mfu: 14.72%
# [titan] 2025-04-21 09:40:29,489 - root - INFO - step: 10  loss: 74.4812  memory: 15.71GiB(8.18%)  tps: 24,702  tflops: 29.88  mfu: 14.72%
# INFO:root:Sleeping 2 seconds for other ranks to complete
# [titan] 2025-04-21 09:40:29,494 - root - INFO - Sleeping 2 seconds for other ranks to complete
# INFO:root:Training completed
# [titan] 2025-04-21 09:40:31,497 - root - INFO - Training completed

# %%
trainer.close()
